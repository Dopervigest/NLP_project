# %%
# !pip install spacy
# !python -m spacy download en_core_web_lg
# !python -m spacy download en_core_web_trf
# Out:
# Requirement already satisfied: spacy in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (2.5.2)
# Requirement already satisfied: jinja2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy) (1.26.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from jinja2->spacy) (2.1.1)
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 6.3 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from en-core-web-lg==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Collecting en-core-web-trf==3.7.3
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_trf-3.7.3/en_core_web_trf-3.7.3-py3-none-any.whl (457.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 6.1 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from en-core-web-trf==3.7.3) (3.7.2)
# Requirement already satisfied: spacy-curated-transformers<0.3.0,>=0.2.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from en-core-web-trf==3.7.3) (0.2.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.5.2)
# Requirement already satisfied: jinja2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.1.2)
# Requirement already satisfied: setuptools in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.26.2)
# Requirement already satisfied: curated-transformers<0.2.0,>=0.1.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (0.1.1)
# Requirement already satisfied: curated-tokenizers<0.1.0,>=0.0.7 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (0.0.8)
# Requirement already satisfied: torch>=1.12.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.1.1)
# Requirement already satisfied: regex>=2022 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from curated-tokenizers<0.1.0,>=0.0.7->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2023.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.1.4)
# Requirement already satisfied: filelock in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.13.1)
# Requirement already satisfied: sympy in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.12)
# Requirement already satisfied: networkx in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (3.2.1)
# Requirement already satisfied: fsspec in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (12.3.101)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-trf==3.7.3) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/vlad/anaconda3/envs/work/lib/python3.9/site-packages (from sympy->torch>=1.12.0->spacy-curated-transformers<0.3.0,>=0.2.0->en-core-web-trf==3.7.3) (1.3.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %% [markdown]
# # The implementations of two pipelines with models from SpaCy library
# ### The two methods used are en_core_web_lg, which is standard SpaCy NER pipeline and en_core_web_trf, which utilises RoBERTa model
# ### Dates are converted to standard format with dateparser library
# ### The models can also be found in ner_models.py

# %%
import spacy
from scripts import load_test_data, test_n_samples, convert_to_standard_date

# %% [markdown]
# # The en_core_web_lg model, optimized for CPU

# %%
class SpacyLgModel():
    def __init__(self):
        self.model = spacy.load("en_core_web_lg")
        
    def extract_flight_details(self, user_request):
        sentence = self.model(user_request)
         
        name = 'Unspecified'
        departure = 'Unspecified'
        destination = 'Unspecified'
        date = 'Unspecified'
         
        for entity in sentence.ents:
            if entity.label_ == 'PERSON' and name == 'Unspecified':
                name = entity.text
            elif entity.label_ in ['NORP', 'GPE', 'LOC']:
                if departure == 'Unspecified':
                    if ' from ' in user_request[:user_request.index(entity.text)]:
                        departure = entity.text
                    elif ' to ' in user_request[:user_request.index(entity.text)]:
                        destination = entity.text
                    else: departure = entity.text
                elif destination == 'Unspecified':
                    destination = entity.text 
            elif entity.label_ == "DATE":  # Recognize date
                date = entity.text
                if 'the ' in date:
                    date = date.replace('the ', '')
                if ' of ' in date:
                    date = date.replace(' of ', ' ')
                if 'around' in date:
                    date = date.replace('around', '')
                date = date.strip()
                date = convert_to_standard_date(date)
                    
        return name, departure, destination, date

# %%
user_requests, required_data = load_test_data()

# %%
model = SpacyLgModel()

# %%
test_n_samples(model, user_requests, required_data,)
# Out:
# Name: Olivia Parker, True_Name: Olivia Parker
# Departure: Barcelona, True_Departure: Barcelona
# Destination: Amsterdam, True_Destination: Amsterdam
# Date: 20-05-2024, True_Date: 20-05-2024
# ---------------------------------------------
# Name: Henry Wright, True_Name: Henry Wright
# Departure: Seoul, True_Departure: Seoul
# Destination: Sydney, True_Destination: Sydney
# Date: 08-09-2024, True_Date: 08-09-2024
# ---------------------------------------------
# Name: Lily Johnson, True_Name: Lily Johnson
# Departure: Rome, True_Departure: Rome
# Destination: Paris, True_Destination: Paris
# Date: 12-07-2024, True_Date: 12-07-2024
# ---------------------------------------------
# Name: Lucas Thompson, True_Name: Lucas Thompson
# Departure: New Delhi, True_Departure: New Delhi
# Destination: Dubai, True_Destination: Dubai
# Date: 30-10-2024, True_Date: 05-10-2024
# ---------------------------------------------
# Name: Isabelle Brown, True_Name: Isabelle Brown
# Departure: Tokyo, True_Departure: Tokyo
# Destination: London, True_Destination: London
# Date: 15-04-2024, True_Date: 15-04-2024
# ---------------------------------------------

# %% [markdown]
# # The en_core_web_trf model

# %%
class SpacyTrfModel():
    def __init__(self):
        self.model = spacy.load("en_core_web_trf")
        
    def extract_flight_details(self, user_request):
        sentence = self.model(user_request)
         
        name = 'Unspecified'
        departure = 'Unspecified'
        destination = 'Unspecified'
        date = 'Unspecified'
         
        for entity in sentence.ents:
            if entity.label_ == 'PERSON' and name == 'Unspecified':
                name = entity.text
            elif entity.label_ in ['NORP', 'GPE', 'LOC']:
                if departure == 'Unspecified':
                    if ' from ' in user_request[:user_request.index(entity.text)]:
                        departure = entity.text
                    elif ' to ' in user_request[:user_request.index(entity.text)]:
                        destination = entity.text
                    else: departure = entity.text
                elif destination == 'Unspecified':
                    destination = entity.text 
            elif entity.label_ == "DATE":  # Recognize date
                date = entity.text
                if 'the ' in date:
                    date = date.replace('the ', '')
                if ' of ' in date:
                    date = date.replace(' of ', ' ')
                if 'around' in date:
                    date = date.replace('around', '')
                date = date.strip()
                date = convert_to_standard_date(date)
                    
        return name, departure, destination, date

# %%
model = SpacyTrfModel()

# %%
test_n_samples(model, user_requests, required_data,)
# Out:
# Name: Olivia Parker, True_Name: Olivia Parker
# Departure: Barcelona, True_Departure: Barcelona
# Destination: Amsterdam, True_Destination: Amsterdam
# Date: 20-05-2024, True_Date: 20-05-2024
# ---------------------------------------------
# Name: Henry Wright, True_Name: Henry Wright
# Departure: Seoul, True_Departure: Seoul
# Destination: Sydney, True_Destination: Sydney
# Date: 08-09-2024, True_Date: 08-09-2024
# ---------------------------------------------
# Name: Lily Johnson, True_Name: Lily Johnson
# Departure: Rome, True_Departure: Rome
# Destination: Paris, True_Destination: Paris
# Date: 12-07-2024, True_Date: 12-07-2024
# ---------------------------------------------
# Name: Lucas Thompson, True_Name: Lucas Thompson
# Departure: New Delhi, True_Departure: New Delhi
# Destination: Dubai, True_Destination: Dubai
# Date: 05-10-2024, True_Date: 05-10-2024
# ---------------------------------------------
# Name: Isabelle Brown, True_Name: Isabelle Brown
# Departure: Tokyo, True_Departure: Tokyo
# Destination: London, True_Destination: London
# Date: 15-04-2024, True_Date: 15-04-2024
# ---------------------------------------------
